# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaythakur3369/CBTCIP/blob/main/Task_3_Time_Series_Forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project - Time Series Forecasting**
# ## **Developed By - Ajay Thakur (ajaythakur3369@gmail.com)**
# ## **Branch Name - Electronics and Communication Engineering**
# ## **Institute Name - Indian Institute of Information Technology Kota (An Institute of National Importance under an Act of Parliament)**
# ## **Submitted To - CipherByte Technologies**
# ## **Project Link (GitHub) - [Click here](https://github.com/ajaythakur3369/CBTCIP/blob/main/Task_3_Time_Series_Forecasting.ipynb)**
# ## **Project Link (Drive) - [Click here](https://colab.research.google.com/drive/15RNVkidXskujRvT6iynAKRBEdf24XKfp)**

# %% [markdown]
# # **Problem Statement -**

# %% [markdown]
# Forecast future trends or values based on historical data. You can use time series models like ARIMA or Prophet and evaluate the model using metrics like RMSE or MAE.
#
# **Dataset -** https://raw.githubusercontent.com/Urnisha2002/CBTCIP/main/TASK3/weather_data_kolkata_2015_2020.csv

# %% [markdown]
# # **Let's Begin !**

# %%
# Import all required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/folders/CB_Weather_Dataset.csv")

# %%
df.head()
# Out:
#               DATETIME  TEMPERATURE  HUMIDITY
# 0  2015-01-01 00:00:00         19.0      75.0
# 1  2015-01-01 01:00:00         19.0      77.0
# 2  2015-01-01 02:00:00         19.0      78.0
# 3  2015-01-01 03:00:00         19.0      80.0
# 4  2015-01-01 04:00:00         19.0      81.0

# %%
df.head(20)
# Out:
#                DATETIME  TEMPERATURE  HUMIDITY
# 0   2015-01-01 00:00:00         19.0      75.0
# 1   2015-01-01 01:00:00         19.0      77.0
# 2   2015-01-01 02:00:00         19.0      78.0
# 3   2015-01-01 03:00:00         19.0      80.0
# 4   2015-01-01 04:00:00         19.0      81.0
# 5   2015-01-01 05:00:00         20.0      83.0
# 6   2015-01-01 06:00:00         20.0      84.0
# 7   2015-01-01 07:00:00         20.0      82.0
# 8   2015-01-01 08:00:00         21.0      80.0
# 9   2015-01-01 09:00:00         22.0      78.0
# 10  2015-01-01 10:00:00         22.0      77.0
# 11  2015-01-01 11:00:00         22.0      76.0
# 12  2015-01-01 12:00:00         23.0      74.0
# 13  2015-01-01 13:00:00         22.0      78.0
# 14  2015-01-01 14:00:00         21.0      83.0
# 15  2015-01-01 15:00:00         20.0      87.0
# 16  2015-01-01 16:00:00         20.0      88.0
# 17  2015-01-01 17:00:00         20.0      90.0
# 18  2015-01-01 18:00:00         20.0      91.0
# 19  2015-01-01 19:00:00         20.0      91.0

# %%
df.tail()
# Out:
#                   DATETIME  TEMPERATURE  HUMIDITY
# 52603  2020-12-31 19:00:00         25.0      36.0
# 52604  2020-12-31 20:00:00         24.0      37.0
# 52605  2020-12-31 21:00:00         23.0      38.0
# 52606  2020-12-31 22:00:00         22.0      39.0
# 52607  2020-12-31 23:00:00         21.0      40.0

# %%
df.tail(20)
# Out:
#                   DATETIME  TEMPERATURE  HUMIDITY
# 52588  2020-12-31 04:00:00         20.0      48.0
# 52589  2020-12-31 05:00:00         20.0      48.0
# 52590  2020-12-31 06:00:00         20.0      49.0
# 52591  2020-12-31 07:00:00         21.0      44.0
# 52592  2020-12-31 08:00:00         23.0      40.0
# 52593  2020-12-31 09:00:00         24.0      36.0
# 52594  2020-12-31 10:00:00         25.0      32.0
# 52595  2020-12-31 11:00:00         26.0      28.0
# 52596  2020-12-31 12:00:00         28.0      25.0
# 52597  2020-12-31 13:00:00         28.0      25.0
# 52598  2020-12-31 14:00:00         28.0      26.0
# 52599  2020-12-31 15:00:00         28.0      26.0
# 52600  2020-12-31 16:00:00         27.0      29.0
# 52601  2020-12-31 17:00:00         26.0      32.0
# 52602  2020-12-31 18:00:00         26.0      35.0
# 52603  2020-12-31 19:00:00         25.0      36.0
# 52604  2020-12-31 20:00:00         24.0      37.0
# 52605  2020-12-31 21:00:00         23.0      38.0
# 52606  2020-12-31 22:00:00         22.0      39.0
# 52607  2020-12-31 23:00:00         21.0      40.0

# %%
df
# Out:
#                   DATETIME  TEMPERATURE  HUMIDITY
# 0      2015-01-01 00:00:00         19.0      75.0
# 1      2015-01-01 01:00:00         19.0      77.0
# 2      2015-01-01 02:00:00         19.0      78.0
# 3      2015-01-01 03:00:00         19.0      80.0
# 4      2015-01-01 04:00:00         19.0      81.0
# ...                    ...          ...       ...
# 52603  2020-12-31 19:00:00         25.0      36.0
# 52604  2020-12-31 20:00:00         24.0      37.0
# 52605  2020-12-31 21:00:00         23.0      38.0
# 52606  2020-12-31 22:00:00         22.0      39.0
# 52607  2020-12-31 23:00:00         21.0      40.0
#
# [52608 rows x 3 columns]

# %%
df.shape
# Out:
# (52608, 3)

# %%
df.dtypes
# Out:
# DATETIME        object
# TEMPERATURE    float64
# HUMIDITY       float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52608 entries, 0 to 52607
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATETIME     52608 non-null  object
#  1   TEMPERATURE  52608 non-null  float64
#  2   HUMIDITY     52608 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#         TEMPERATURE      HUMIDITY
# count  52608.000000  52608.000000
# mean      28.187633     58.871693
# std        4.946404     18.935218
# min       11.000000      8.000000
# 25%       25.000000     44.000000
# 50%       29.000000     60.000000
# 75%       31.000000     75.000000
# max       45.000000     98.000000

# %%
df.describe().T
# Out:
#                count       mean        std   min   25%   50%   75%   max
# TEMPERATURE  52608.0  28.187633   4.946404  11.0  25.0  29.0  31.0  45.0
# HUMIDITY     52608.0  58.871693  18.935218   8.0  44.0  60.0  75.0  98.0

# %%
df.isnull().sum()
# Out:
# DATETIME       0
# TEMPERATURE    0
# HUMIDITY       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Finding Out Co-Relation**

# %%
corr=df.corr()
corr
# Out:
#              TEMPERATURE  HUMIDITY
# TEMPERATURE     1.000000 -0.071982
# HUMIDITY       -0.071982  1.000000

# %% [markdown]
# **Heat Map**

# %%
sns.heatmap(df.corr(), annot = True)
plt.show()

# %% [markdown]
# **INFERENCE:**
#
# **"TEMPERATURE":**
#
# The typical temperature is roughly 28.19°C.
#
# The standard deviation of temperature is just 4.95°C.
#
# The temperature range is 11.0 to 45.0 degrees Celsius.
#
# Temperatures in the middle 50% range from 25.0°C to 31.0°C.
#
# **"HUMIDITY":**
#
# The relative humidity is about 58.87% on average.
#
# The standard variation of humidity data is greater at roughly 18.94%.
#
# 8.0% to 98.0% of the air is humid.
#
# Humidity levels in the middle 50% range from 44.0% to 75.0%.

# %% [markdown]
# **DATA PRE - PROCESSING**

# %%
df['DATETIME'] = pd.to_datetime(df['DATETIME'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52608 entries, 0 to 52607
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATETIME     52608 non-null  datetime64[ns]
#  1   TEMPERATURE  52608 non-null  float64
#  2   HUMIDITY     52608 non-null  float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 1.2 MB

# %%
df.head(25)
# Out:
#               DATETIME  TEMPERATURE  HUMIDITY
# 0  2015-01-01 00:00:00         19.0      75.0
# 1  2015-01-01 01:00:00         19.0      77.0
# 2  2015-01-01 02:00:00         19.0      78.0
# 3  2015-01-01 03:00:00         19.0      80.0
# 4  2015-01-01 04:00:00         19.0      81.0
# 5  2015-01-01 05:00:00         20.0      83.0
# 6  2015-01-01 06:00:00         20.0      84.0
# 7  2015-01-01 07:00:00         20.0      82.0
# 8  2015-01-01 08:00:00         21.0      80.0
# 9  2015-01-01 09:00:00         22.0      78.0
# 10 2015-01-01 10:00:00         22.0      77.0
# 11 2015-01-01 11:00:00         22.0      76.0
# 12 2015-01-01 12:00:00         23.0      74.0
# 13 2015-01-01 13:00:00         22.0      78.0
# 14 2015-01-01 14:00:00         21.0      83.0
# 15 2015-01-01 15:00:00         20.0      87.0
# 16 2015-01-01 16:00:00         20.0      88.0
# 17 2015-01-01 17:00:00         20.0      90.0
# 18 2015-01-01 18:00:00         20.0      91.0
# 19 2015-01-01 19:00:00         20.0      91.0
# 20 2015-01-01 20:00:00         20.0      91.0
# 21 2015-01-01 21:00:00         20.0      91.0
# 22 2015-01-01 22:00:00         20.0      91.0
# 23 2015-01-01 23:00:00         20.0      91.0
# 24 2015-01-02 00:00:00         20.0      91.0

# %% [markdown]
# **INFERENCE :**
#
# For each date, there are hourly temperature and humidity readings. It is necessary to compute the average values in order to get the date-based mean temperature and mean humidity.

# %%
df['DATE'] = df['DATETIME'].dt.date
df
# Out:
#                  DATETIME  TEMPERATURE  HUMIDITY        DATE
# 0     2015-01-01 00:00:00         19.0      75.0  2015-01-01
# 1     2015-01-01 01:00:00         19.0      77.0  2015-01-01
# 2     2015-01-01 02:00:00         19.0      78.0  2015-01-01
# 3     2015-01-01 03:00:00         19.0      80.0  2015-01-01
# 4     2015-01-01 04:00:00         19.0      81.0  2015-01-01
# ...                   ...          ...       ...         ...
# 52603 2020-12-31 19:00:00         25.0      36.0  2020-12-31
# 52604 2020-12-31 20:00:00         24.0      37.0  2020-12-31
# 52605 2020-12-31 21:00:00         23.0      38.0  2020-12-31
# 52606 2020-12-31 22:00:00         22.0      39.0  2020-12-31
# 52607 2020-12-31 23:00:00         21.0      40.0  2020-12-31
#
# [52608 rows x 4 columns]

# %% [markdown]
# **Calculating the average temperature and humidity for a group of data using the date.**

# %%
datewise_df = df.groupby('DATE').agg({'TEMPERATURE': 'mean', 'HUMIDITY': 'mean'}).reset_index()
datewise_df
# Out:
#             DATE  TEMPERATURE   HUMIDITY
# 0     2015-01-01    20.333333  83.208333
# 1     2015-01-02    23.041667  76.208333
# 2     2015-01-03    24.375000  76.750000
# 3     2015-01-04    23.916667  68.250000
# 4     2015-01-05    21.250000  51.375000
# ...          ...          ...        ...
# 2187  2020-12-27    23.083333  28.583333
# 2188  2020-12-28    23.958333  30.250000
# 2189  2020-12-29    24.750000  32.458333
# 2190  2020-12-30    23.875000  34.125000
# 2191  2020-12-31    23.541667  37.375000
#
# [2192 rows x 3 columns]

# %%
datewise_df.shape
# Out:
# (2192, 3)

# %% [markdown]
# **DATA VISUALISATION**

# %%
plt.rcParams['figure.figsize'] = (15, 6)
fig = px.line(datewise_df, x = "DATE", y = "TEMPERATURE", title = 'Temperature of Kolkata Over the Years 2015 - 2020', color_discrete_sequence = ['blue'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9aba5e32-b4a7-429b-a7f0-63e888a9f50d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9aba5e32-b4a7-429b-a7f0-63e888a9f50d")) {                    Plotly.newPlot(                        "9aba5e32-b4a7-429b-a7f0-63e888a9f50d",                        [{"hovertemplate":"DATE=%{x}\u003cbr\u003eTEMPERATURE=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"blue","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2015-01-01","2015-01-02","2015-01-03","2015-01-04","2015-01-05","2015-01-06","2015-01-07","2015-01-08","2015-01-09","2015-01-10","2015-01-11","2015-01-12","2015-01-13","2015-01-14","2015-01-15","2015-01-16","2015-01-17","2015-01-18","2015-01-19","2015-01-20","2015-01-21","2015-01-22","2015-01-23","2015-01-24","2015-01-25","2015-01-26","2015-01-27","2015-01-28","2015-01-29","2015-01-30","2015-01-31","2015-02-01","2015-02-02","2015-02-03","2015-02-04","2015-02-05","2015-02-06","2015-02-07","2015-02-08","2015-02-09","2015-02-10","2015-02-11","2015-02-12","2015-02-13","2015-02-14","2015-02-15","2015-02-16","2015-02-17","2015-02-18","2015-02-19","2015-02-20","2015-02-21","2015-02-22","2015-02-23","2015-02-24","2015-02-25","2015-02-26","2015-02-27","2015-02-28","2015-03-01","2015-03-02","2015-03-03","2015-03-04","2015-03-05","2015-03-06","2015-03-07","2015-03-08","2015-03-09","2015-03-10","2015-03-11","2015-03-12","2015-03-13","2015-03-14","2015-03-15","2015-03-16","2015-03-17","2015-03-18","2015-03-19","2015-03-20","2015-03-21","2015-03-22","2015-03-23","2015-03-24","2015-03-25","2015-03-26","2015-03-27","2015-03-28","2015-03-29","2015-03-30","2015-03-31","2015-04-01","2015-04-02","2015-04-03","2015-04-04","2015-04-05","2015-04-06","2015-04-07","2015-04-08","2015-04-09","2015-04-10","2015-04-11","2015-04-12","2015-04-13","2015-04-14","2015-04-15","2015-04-16","2015-04-17","2015-04-18","2015-04-19","2015-04-20","2015-04-21","2015-04-22","2015-04-23","2015-04-24","2015-04-25","2015-04-26","2015-04-27","2015-04-28","2015-04-29","2015-04-30","2015-05-01","2015-05-02","2015-05-03","2015-05-04","2015-05-05","2015-05-06","2015-05-07","2015-05-08","2015-05-09","2015-05-10","2015-05-11","2015-05-12","2015-05-13","2015-05-14","2015-05-15","2015-05-16","2015-05-17","2015-05-18","2015-05-19","2015-05-20","2015-05-21","2015-05-22","2015-05-23","2015-05-24","2015-05-25","2015-05-26","2015-05-27","2015-05-28","2015-05-29","2015-05-30","2015-05-31","2015-06-01","2015-06-02","2015-06-03","2015-06-04","2015-06-05","2015-06-06","2015-06-07","2015-06-08","2015-06-09","2015-06-10","2015-06-11","2015-06-12","2015-06-13","2015-06-14","2015-06-15","2015-06-16","2015-06-17","2015-06-18","2015-06-19","2015-06-20","2015-06-21","2015-06-22","2015-06-23","2015-06-24","2015-06-25","2015-06-26","2015-06-27","2015-06-28","2015-06-29","2015-06-30","2015-07-01","2015-07-02","2015-07-03","2015-07-04","2015-07-05","2015-07-06","2015-07-07","2015-07-08","2015-07-09","2015-07-10","2015-07-11","2015-07-12","2015-07-13","2015-07-14","2015-07-15","2015-07-16","2015-07-17","2015-07-18","2015-07-19","2015-07-20","2015-07-21","2015-07-22","2015-07-23","2015-07-24","2015-07-25","2015-07-26","2015-07-27","2015-07-28","2015-07-29","2015-07-30","2015-07-31","2015-08-01","2015-08-02","2015-08-03","2015-08-04","2015-08-05","2015-08-06","2015-08-07","2015-08-08","2015-08-09","2015-08-10","2015-08-11","2015-08-12","2015-08-13","2015-08-14","2015-08-15","2015-08-16","2015-08-17","2015-08-18","2015-08-19","2015-08-20","2015-08-21","2015-08-22","2015-08-23","2015-08-24","2015-08-25","2015-08-26","2015-08-27","2015-08-28","2015-08-29","2015-08-30","2015-08-31","2015-09-01","2015-09-02","2015-09-03","2015 ...

# %%
fig = px.line(datewise_df, x = "DATE", y = "HUMIDITY", title = 'Humidity of Kolkata Over the Years', color_discrete_sequence = ['red'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="eef9de6f-3951-4e10-ae51-6c73f5f700a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eef9de6f-3951-4e10-ae51-6c73f5f700a6")) {                    Plotly.newPlot(                        "eef9de6f-3951-4e10-ae51-6c73f5f700a6",                        [{"hovertemplate":"DATE=%{x}\u003cbr\u003eHUMIDITY=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"red","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2015-01-01","2015-01-02","2015-01-03","2015-01-04","2015-01-05","2015-01-06","2015-01-07","2015-01-08","2015-01-09","2015-01-10","2015-01-11","2015-01-12","2015-01-13","2015-01-14","2015-01-15","2015-01-16","2015-01-17","2015-01-18","2015-01-19","2015-01-20","2015-01-21","2015-01-22","2015-01-23","2015-01-24","2015-01-25","2015-01-26","2015-01-27","2015-01-28","2015-01-29","2015-01-30","2015-01-31","2015-02-01","2015-02-02","2015-02-03","2015-02-04","2015-02-05","2015-02-06","2015-02-07","2015-02-08","2015-02-09","2015-02-10","2015-02-11","2015-02-12","2015-02-13","2015-02-14","2015-02-15","2015-02-16","2015-02-17","2015-02-18","2015-02-19","2015-02-20","2015-02-21","2015-02-22","2015-02-23","2015-02-24","2015-02-25","2015-02-26","2015-02-27","2015-02-28","2015-03-01","2015-03-02","2015-03-03","2015-03-04","2015-03-05","2015-03-06","2015-03-07","2015-03-08","2015-03-09","2015-03-10","2015-03-11","2015-03-12","2015-03-13","2015-03-14","2015-03-15","2015-03-16","2015-03-17","2015-03-18","2015-03-19","2015-03-20","2015-03-21","2015-03-22","2015-03-23","2015-03-24","2015-03-25","2015-03-26","2015-03-27","2015-03-28","2015-03-29","2015-03-30","2015-03-31","2015-04-01","2015-04-02","2015-04-03","2015-04-04","2015-04-05","2015-04-06","2015-04-07","2015-04-08","2015-04-09","2015-04-10","2015-04-11","2015-04-12","2015-04-13","2015-04-14","2015-04-15","2015-04-16","2015-04-17","2015-04-18","2015-04-19","2015-04-20","2015-04-21","2015-04-22","2015-04-23","2015-04-24","2015-04-25","2015-04-26","2015-04-27","2015-04-28","2015-04-29","2015-04-30","2015-05-01","2015-05-02","2015-05-03","2015-05-04","2015-05-05","2015-05-06","2015-05-07","2015-05-08","2015-05-09","2015-05-10","2015-05-11","2015-05-12","2015-05-13","2015-05-14","2015-05-15","2015-05-16","2015-05-17","2015-05-18","2015-05-19","2015-05-20","2015-05-21","2015-05-22","2015-05-23","2015-05-24","2015-05-25","2015-05-26","2015-05-27","2015-05-28","2015-05-29","2015-05-30","2015-05-31","2015-06-01","2015-06-02","2015-06-03","2015-06-04","2015-06-05","2015-06-06","2015-06-07","2015-06-08","2015-06-09","2015-06-10","2015-06-11","2015-06-12","2015-06-13","2015-06-14","2015-06-15","2015-06-16","2015-06-17","2015-06-18","2015-06-19","2015-06-20","2015-06-21","2015-06-22","2015-06-23","2015-06-24","2015-06-25","2015-06-26","2015-06-27","2015-06-28","2015-06-29","2015-06-30","2015-07-01","2015-07-02","2015-07-03","2015-07-04","2015-07-05","2015-07-06","2015-07-07","2015-07-08","2015-07-09","2015-07-10","2015-07-11","2015-07-12","2015-07-13","2015-07-14","2015-07-15","2015-07-16","2015-07-17","2015-07-18","2015-07-19","2015-07-20","2015-07-21","2015-07-22","2015-07-23","2015-07-24","2015-07-25","2015-07-26","2015-07-27","2015-07-28","2015-07-29","2015-07-30","2015-07-31","2015-08-01","2015-08-02","2015-08-03","2015-08-04","2015-08-05","2015-08-06","2015-08-07","2015-08-08","2015-08-09","2015-08-10","2015-08-11","2015-08-12","2015-08-13","2015-08-14","2015-08-15","2015-08-16","2015-08-17","2015-08-18","2015-08-19","2015-08-20","2015-08-21","2015-08-22","2015-08-23","2015-08-24","2015-08-25","2015-08-26","2015-08-27","2015-08-28","2015-08-29","2015-08-30","2015-08-31","2015-09-01","2015-09-02","2015-09-03","2015-09- ...

# %% [markdown]
# **Converting date column to datetime**

# %%
datewise_df['DATE'] = pd.to_datetime(datewise_df['DATE'])

# %%
plt.figure(figsize = (40, 10))
plt.yticks(rotation = 90,fontsize = 15)
plt.xlabel("DATE", fontsize = 30)
plt.ylabel("TEMPERATURE", fontsize = 30)

plt.title("Date - wise Temperature of Kolkata", fontsize = 30)

ax = sns.pointplot(x = datewise_df['DATE'].dt.date, y = datewise_df['TEMPERATURE'], color = 'g')
ax.set(xlabel = "DATE", ylabel = "TEMPERATURE")

plt.show()

# %%
plt.figure(figsize = (40, 10))
plt.yticks(rotation = 90,fontsize = 15)
plt.xlabel("DATE", fontsize = 30)
plt.ylabel("HUMIDITY", fontsize = 30)

plt.title("Date - wise Humidity of Kolkata", fontsize = 30)

ax = sns.pointplot(x = datewise_df['DATE'].dt.date, y = datewise_df['HUMIDITY'], color = 'b')
ax.set(xlabel = "DATE", ylabel = "HUMIDITY")

plt.show()

# %% [markdown]
# **Scatter Plot**

# %%
figure = px.scatter(data_frame = datewise_df, x = "HUMIDITY", y = "TEMPERATURE",
                    trendline = "ols",
                    title = "Relationship Between Temperature and Humidity",
                    color_discrete_sequence = ['red'])
figure.update_traces(line = dict(color = 'green'))
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e4b0960a-3f1c-47fc-8aae-6ac5671c8861" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4b0960a-3f1c-47fc-8aae-6ac5671c8861")) {                    Plotly.newPlot(                        "e4b0960a-3f1c-47fc-8aae-6ac5671c8861",                        [{"hovertemplate":"HUMIDITY=%{x}\u003cbr\u003eTEMPERATURE=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"red","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[83.20833333333333,76.20833333333333,76.75,68.25,51.375,49.833333333333336,47.333333333333336,44.5,50.166666666666664,46.083333333333336,36.916666666666664,30.791666666666668,33.75,46.041666666666664,44.625,46.666666666666664,34.875,34.333333333333336,39.875,39.166666666666664,30.958333333333332,33.916666666666664,37.0,43.541666666666664,47.875,41.291666666666664,46.125,54.375,55.666666666666664,48.583333333333336,35.416666666666664,31.208333333333332,32.416666666666664,30.166666666666668,33.375,39.375,34.875,27.125,34.541666666666664,41.833333333333336,43.958333333333336,34.208333333333336,32.583333333333336,43.291666666666664,40.708333333333336,53.875,58.375,58.75,67.33333333333333,62.708333333333336,55.875,47.541666666666664,44.583333333333336,52.208333333333336,49.541666666666664,48.5,59.041666666666664,57.708333333333336,55.083333333333336,48.875,45.875,50.5,57.5,35.25,31.166666666666668,28.166666666666668,30.916666666666668,27.708333333333332,38.291666666666664,47.625,45.125,42.708333333333336,41.125,42.375,43.75,47.75,49.625,44.375,35.583333333333336,34.666666666666664,36.208333333333336,40.291666666666664,58.458333333333336,59.958333333333336,61.833333333333336,59.166666666666664,58.958333333333336,62.875,63.375,44.666666666666664,55.625,56.166666666666664,48.333333333333336,61.666666666666664,71.25,75.45833333333333,67.70833333333333,64.70833333333333,45.083333333333336,51.916666666666664,56.625,54.25,53.166666666666664,52.083333333333336,53.0,41.541666666666664,45.583333333333336,49.583333333333336,59.083333333333336,60.458333333333336,55.416666666666664,61.958333333333336,48.0,61.0,63.375,62.958333333333336,59.416666666666664,56.958333333333336,66.625,71.66666666666667,65.04166666666667,71.04166666666667,65.0,58.125,56.416666666666664,53.125,56.083333333333336,58.833333333333336,69.20833333333333,59.75,63.125,49.208333333333336,56.291666666666664,57.708333333333336,52.833333333333336,58.333333333333336,65.875,56.625,59.875,56.458333333333336,51.416666666666664,60.875,65.45833333333333,66.5,68.08333333333333,68.54166666666667,66.75,64.41666666666667,62.166666666666664,61.208333333333336,61.125,61.208333333333336,59.5,58.708333333333336,60.625,55.333333333333336,59.333333333333336,59.041666666666664,57.166666666666664,60.458333333333336,56.75,65.20833333333333,59.666666666666664,61.75,63.791666666666664,66.33333333333333,75.54166666666667,65.58333333333333,61.666666666666664,61.708333333333336,64.08333333333333,70.83333333333333,70.95833333333333,70.79166666666667,69.83333333333333,76.20833333333333,76.41666666666667,71.08333333333333,67.33333333333333,66.0,66.91666666666667,64.04166666666667,66.125,64.16666666666667,63.541666666666664,69.70833333333333,73.29166666666667,77.04166666666667,80.16666666666667,83.625,78.66666666666667,72.29166666666667,70.58333333333333,71.08333333333333,71.08333333333333,72.41666666666667,77.75,75.04166666666667,76.0,76.41666666666667,84.625,72.79166666666667,71.29166666666667,72.5,69.04166666666667,86.54166666666667,79.91666666666667,90.91666666666667,86.08333333333333,78.45833333333333,79.875,87.29166666666667,89.20833333333333,85.20833333333333,75.875,74.70833333333333,73.83333333333333,69.79166666666667,70.5,72.3333333333 ...

# %% [markdown]
# **Inference :**
#
# A relatively favorable association between temperature and humidity is shown in the graph.

# %% [markdown]
# **Fetching Year and month from the date**

# %%
datewise_df['Year'] = datewise_df["DATE"].dt.year
datewise_df["Month"] = datewise_df["DATE"].dt.month

# %%
datewise_df.head()
# Out:
#         DATE  TEMPERATURE   HUMIDITY  Year  Month
# 0 2015-01-01    20.333333  83.208333  2015      1
# 1 2015-01-02    23.041667  76.208333  2015      1
# 2 2015-01-03    24.375000  76.750000  2015      1
# 3 2015-01-04    23.916667  68.250000  2015      1
# 4 2015-01-05    21.250000  51.375000  2015      1

# %% [markdown]
# **Plotting changes in temparature over years 2015 - 2020**

# %%
plt.figure(figsize = (15, 6))
plt.style.use('Solarize_Light2')
plt.title("Changes in Temperature Over the Years in Kolkata", fontname = 'serif', fontsize = 16)
sns.lineplot(data = datewise_df, x = 'Month', y = 'TEMPERATURE', hue = 'Year')
plt.show()

# %% [markdown]
# **Plotting changes in humidity over years 2015 - 2020**

# %%
plt.figure(figsize = (15, 6))
plt.style.use('Solarize_Light2')
plt.title(" Changes in Humidity Over the Years in Kolkata", fontname = 'serif', fontsize = 16)
sns.lineplot(data = datewise_df, x = 'Month', y = 'HUMIDITY', hue = 'Year')
plt.show()

# %% [markdown]
# **Inferences:**
#
# It is clear that Kolkata saw lower temperatures and humidity in 2020 than in earlier years.

# %% [markdown]
# **PREDICT TEMPARATURE USING PROPHET**
#
# **Data Pre-Processing**

# %%
forecast_df = datewise_df.rename(columns = {"DATE": "ds",
                                       "TEMPERATURE": "y"})

# %%
forecast_df.head()
# Out:
#           ds          y   HUMIDITY  Year  Month
# 0 2015-01-01  20.333333  83.208333  2015      1
# 1 2015-01-02  23.041667  76.208333  2015      1
# 2 2015-01-03  24.375000  76.750000  2015      1
# 3 2015-01-04  23.916667  68.250000  2015      1
# 4 2015-01-05  21.250000  51.375000  2015      1

# %%
forecast_temperature_df = forecast_df.drop(['HUMIDITY', 'Year', 'Month'], axis = 1)

# %%
forecast_temperature_df.head()
# Out:
#           ds          y
# 0 2015-01-01  20.333333
# 1 2015-01-02  23.041667
# 2 2015-01-03  24.375000
# 3 2015-01-04  23.916667
# 4 2015-01-05  21.250000

# %% [markdown]
# **Importing necessary libraries**

# %%
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly
import plotly.graph_objs as go

# %%
model_t = Prophet()

# %%
model_t.fit(forecast_temperature_df)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpk1uljqa6/9nt5l_7a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpk1uljqa6/hjfddo_i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22587', 'data', 'file=/tmp/tmpk1uljqa6/9nt5l_7a.json', 'init=/tmp/tmpk1uljqa6/hjfddo_i.json', 'output', 'file=/tmp/tmpk1uljqa6/prophet_model9ahf8kfs/prophet_model-20231126041728.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:17:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:17:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
forecasts_t = model_t.make_future_dataframe(periods = 365)

# %%
predictions_t = model_t.predict(forecasts_t)

# %%
fig_t = plot_plotly(model_t, predictions_t)

# %%
fig_t.update_layout(title = "Temperature Forecast using Prophet")
fig_t.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b95dcc0f-f4e6-4faf-899a-7b53e4daaf12" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b95dcc0f-f4e6-4faf-899a-7b53e4daaf12")) {                    Plotly.newPlot(                        "b95dcc0f-f4e6-4faf-899a-7b53e4daaf12",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"Actual","x":["2015-01-01T00:00:00","2015-01-02T00:00:00","2015-01-03T00:00:00","2015-01-04T00:00:00","2015-01-05T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-10T00:00:00","2015-01-11T00:00:00","2015-01-12T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-17T00:00:00","2015-01-18T00:00:00","2015-01-19T00:00:00","2015-01-20T00:00:00","2015-01-21T00:00:00","2015-01-22T00:00:00","2015-01-23T00:00:00","2015-01-24T00:00:00","2015-01-25T00:00:00","2015-01-26T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-29T00:00:00","2015-01-30T00:00:00","2015-01-31T00:00:00","2015-02-01T00:00:00","2015-02-02T00:00:00","2015-02-03T00:00:00","2015-02-04T00:00:00","2015-02-05T00:00:00","2015-02-06T00:00:00","2015-02-07T00:00:00","2015-02-08T00:00:00","2015-02-09T00:00:00","2015-02-10T00:00:00","2015-02-11T00:00:00","2015-02-12T00:00:00","2015-02-13T00:00:00","2015-02-14T00:00:00","2015-02-15T00:00:00","2015-02-16T00:00:00","2015-02-17T00:00:00","2015-02-18T00:00:00","2015-02-19T00:00:00","2015-02-20T00:00:00","2015-02-21T00:00:00","2015-02-22T00:00:00","2015-02-23T00:00:00","2015-02-24T00:00:00","2015-02-25T00:00:00","2015-02-26T00:00:00","2015-02-27T00:00:00","2015-02-28T00:00:00","2015-03-01T00:00:00","2015-03-02T00:00:00","2015-03-03T00:00:00","2015-03-04T00:00:00","2015-03-05T00:00:00","2015-03-06T00:00:00","2015-03-07T00:00:00","2015-03-08T00:00:00","2015-03-09T00:00:00","2015-03-10T00:00:00","2015-03-11T00:00:00","2015-03-12T00:00:00","2015-03-13T00:00:00","2015-03-14T00:00:00","2015-03-15T00:00:00","2015-03-16T00:00:00","2015-03-17T00:00:00","2015-03-18T00:00:00","2015-03-19T00:00:00","2015-03-20T00:00:00","2015-03-21T00:00:00","2015-03-22T00:00:00","2015-03-23T00:00:00","2015-03-24T00:00:00","2015-03-25T00:00:00","2015-03-26T00:00:00","2015-03-27T00:00:00","2015-03-28T00:00:00","2015-03-29T00:00:00","2015-03-30T00:00:00","2015-03-31T00:00:00","2015-04-01T00:00:00","2015-04-02T00:00:00","2015-04-03T00:00:00","2015-04-04T00:00:00","2015-04-05T00:00:00","2015-04-06T00:00:00","2015-04-07T00:00:00","2015-04-08T00:00:00","2015-04-09T00:00:00","2015-04-10T00:00:00","2015-04-11T00:00:00","2015-04-12T00:00:00","2015-04-13T00:00:00","2015-04-14T00:00:00","2015-04-15T00:00:00","2015-04-16T00:00:00","2015-04-17T00:00:00","2015-04-18T00:00:00","2015-04-19T00:00:00","2015-04-20T00:00:00","2015-04-21T00:00:00","2015-04-22T00:00:00","2015-04-23T00:00:00","2015-04-24T00:00:00","2015-04-25T00:00:00","2015-04-26T00:00:00","2015-04-27T00:00:00","2015-04-28T00:00:00","2015-04-29T00:00:00","2015-04-30T00:00:00","2015-05-01T00:00:00","2015-05-02T00:00:00","2015-05-03T00:00:00","2015-05-04T00:00:00","2015-05-05T00:00:00","2015-05-06T00:00:00","2015-05-07T00:00:00","2015-05-08T00:00:00","2015-05-09T00:00:00","2015-05-10T00:00:00","2015-05-11T00:00:00","2015-05-12T00:00:00","2015-05-13T00:00:00","2015-05-14T00:00:00","2015-05-15T00:00:00","2015-05-16T00:00:00","2015-05-17T00:00:00","2015-05-18T00:00:00","2015-05-19T00:00:00","2015-05-20T00:00:00","2015-05-21T00:00:00","2015-05-22T00:00:00","2015-05-23T00:00:00","2015-05-24T00:00:00","2015-05-25T00:00:00","2015-05-26T00:00:00","2015-05-27T00:00:00","2015-05-28T00:00:00","2015-05-29T00:00:00","2015-05-30T00:00:00","2015-05-31T00:00:00","2015-06-01T00:00:00","2015-06-02T00:0 ...

# %% [markdown]
# **Model evaluation using RMSE and MAE**

# %%
actual_temp_values = forecast_temperature_df['y'].values

predicted_temp_values = predictions_t['yhat'].values[:len(actual_temp_values)]

rmse = np.sqrt(mean_squared_error(actual_temp_values, predicted_temp_values))
mae = mean_absolute_error(actual_temp_values, predicted_temp_values)

print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")
# Out:
# Root Mean Squared Error (RMSE): 1.5064097634234772
# Mean Absolute Error (MAE): 1.1299678006141685

# %% [markdown]
# Inference:
#
# 1.   The RMSE value of 1.51 shows that the predicted values from the model are typically 1.51 units off from the actual values. This low score shows that the model's forecasts typically match the measured data quite well.
# 2.   The absolute difference between the anticipated and actual values is typically around 1.13 units, according to the MAE value of 1.13. Better forecast accuracy is indicated by a lower MAE.
# 3.   The low RMSE and MAE values imply that the model's predictions are precise and deviate from the actual values very slightly. This shows that the model and the data are well-matched, and the model is probably doing a good job of forecasting the desired variable.

# %%
forecast_humidity_df = datewise_df[['DATE', 'HUMIDITY']]

# %%
forecast_humidity_df.head()
# Out:
#         DATE   HUMIDITY
# 0 2015-01-01  83.208333
# 1 2015-01-02  76.208333
# 2 2015-01-03  76.750000
# 3 2015-01-04  68.250000
# 4 2015-01-05  51.375000

# %%
forecast_humidity_df = forecast_humidity_df.rename(columns={"DATE" : "ds", "HUMIDITY": "y"})

# %%
forecast_humidity_df.head()
# Out:
#           ds          y
# 0 2015-01-01  83.208333
# 1 2015-01-02  76.208333
# 2 2015-01-03  76.750000
# 3 2015-01-04  68.250000
# 4 2015-01-05  51.375000

# %%
model_h = Prophet()

# %%
model_h.fit(forecast_humidity_df)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpk1uljqa6/ho16mym0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpk1uljqa6/akexr09m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12616', 'data', 'file=/tmp/tmpk1uljqa6/ho16mym0.json', 'init=/tmp/tmpk1uljqa6/akexr09m.json', 'output', 'file=/tmp/tmpk1uljqa6/prophet_model06krs6_3/prophet_model-20231126041731.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:17:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:17:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
forecasts_h = model_h.make_future_dataframe(periods = 365)

# %%
predictions_h = model_h.predict(forecasts_h)

# %%
fig_h = plot_plotly(model_h, predictions_h)

# %%
fig_h.update_layout(title = "Humidity Forecast Using Prophet")
fig_h.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b5f3c907-cd55-4e0e-862a-8b4f769db76c" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5f3c907-cd55-4e0e-862a-8b4f769db76c")) {                    Plotly.newPlot(                        "b5f3c907-cd55-4e0e-862a-8b4f769db76c",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"Actual","x":["2015-01-01T00:00:00","2015-01-02T00:00:00","2015-01-03T00:00:00","2015-01-04T00:00:00","2015-01-05T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-10T00:00:00","2015-01-11T00:00:00","2015-01-12T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-17T00:00:00","2015-01-18T00:00:00","2015-01-19T00:00:00","2015-01-20T00:00:00","2015-01-21T00:00:00","2015-01-22T00:00:00","2015-01-23T00:00:00","2015-01-24T00:00:00","2015-01-25T00:00:00","2015-01-26T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-29T00:00:00","2015-01-30T00:00:00","2015-01-31T00:00:00","2015-02-01T00:00:00","2015-02-02T00:00:00","2015-02-03T00:00:00","2015-02-04T00:00:00","2015-02-05T00:00:00","2015-02-06T00:00:00","2015-02-07T00:00:00","2015-02-08T00:00:00","2015-02-09T00:00:00","2015-02-10T00:00:00","2015-02-11T00:00:00","2015-02-12T00:00:00","2015-02-13T00:00:00","2015-02-14T00:00:00","2015-02-15T00:00:00","2015-02-16T00:00:00","2015-02-17T00:00:00","2015-02-18T00:00:00","2015-02-19T00:00:00","2015-02-20T00:00:00","2015-02-21T00:00:00","2015-02-22T00:00:00","2015-02-23T00:00:00","2015-02-24T00:00:00","2015-02-25T00:00:00","2015-02-26T00:00:00","2015-02-27T00:00:00","2015-02-28T00:00:00","2015-03-01T00:00:00","2015-03-02T00:00:00","2015-03-03T00:00:00","2015-03-04T00:00:00","2015-03-05T00:00:00","2015-03-06T00:00:00","2015-03-07T00:00:00","2015-03-08T00:00:00","2015-03-09T00:00:00","2015-03-10T00:00:00","2015-03-11T00:00:00","2015-03-12T00:00:00","2015-03-13T00:00:00","2015-03-14T00:00:00","2015-03-15T00:00:00","2015-03-16T00:00:00","2015-03-17T00:00:00","2015-03-18T00:00:00","2015-03-19T00:00:00","2015-03-20T00:00:00","2015-03-21T00:00:00","2015-03-22T00:00:00","2015-03-23T00:00:00","2015-03-24T00:00:00","2015-03-25T00:00:00","2015-03-26T00:00:00","2015-03-27T00:00:00","2015-03-28T00:00:00","2015-03-29T00:00:00","2015-03-30T00:00:00","2015-03-31T00:00:00","2015-04-01T00:00:00","2015-04-02T00:00:00","2015-04-03T00:00:00","2015-04-04T00:00:00","2015-04-05T00:00:00","2015-04-06T00:00:00","2015-04-07T00:00:00","2015-04-08T00:00:00","2015-04-09T00:00:00","2015-04-10T00:00:00","2015-04-11T00:00:00","2015-04-12T00:00:00","2015-04-13T00:00:00","2015-04-14T00:00:00","2015-04-15T00:00:00","2015-04-16T00:00:00","2015-04-17T00:00:00","2015-04-18T00:00:00","2015-04-19T00:00:00","2015-04-20T00:00:00","2015-04-21T00:00:00","2015-04-22T00:00:00","2015-04-23T00:00:00","2015-04-24T00:00:00","2015-04-25T00:00:00","2015-04-26T00:00:00","2015-04-27T00:00:00","2015-04-28T00:00:00","2015-04-29T00:00:00","2015-04-30T00:00:00","2015-05-01T00:00:00","2015-05-02T00:00:00","2015-05-03T00:00:00","2015-05-04T00:00:00","2015-05-05T00:00:00","2015-05-06T00:00:00","2015-05-07T00:00:00","2015-05-08T00:00:00","2015-05-09T00:00:00","2015-05-10T00:00:00","2015-05-11T00:00:00","2015-05-12T00:00:00","2015-05-13T00:00:00","2015-05-14T00:00:00","2015-05-15T00:00:00","2015-05-16T00:00:00","2015-05-17T00:00:00","2015-05-18T00:00:00","2015-05-19T00:00:00","2015-05-20T00:00:00","2015-05-21T00:00:00","2015-05-22T00:00:00","2015-05-23T00:00:00","2015-05-24T00:00:00","2015-05-25T00:00:00","2015-05-26T00:00:00","2015-05-27T00:00:00","2015-05-28T00:00:00","2015-05-29T00:00:00","2015-05-30T00:00:00","2015-05-31T00:00:00","2015-06-01T00:00:00","2015-06-02T00:0 ...

# %% [markdown]
# **Model evaluation using RMSE and MAE**

# %%
actual_humidity_values = forecast_humidity_df['y'].values

# %%
predicted_humidity_values = predictions_h['yhat'].values[:len(actual_humidity_values)]

# %%
rmse = np.sqrt(mean_squared_error(actual_humidity_values, predicted_humidity_values))
mae = mean_absolute_error(actual_humidity_values, predicted_humidity_values)

# %%
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")
# Out:
# Root Mean Squared Error (RMSE): 8.47388444245433
# Mean Absolute Error (MAE): 6.310149354394203

# %% [markdown]
# **Inference:**
#
# 1.   According to the RMSE value of 33.43, the predicted values typically differ from the actual values by about 33.43 units.
# 2.   The MAE value of 30.71 shows that, on average, there are about 30.71 units between the expected and actual values.
# 3.   The results show that the model's predictions are to a certain extent correct, but there may be an opportunity for development to further minimize the mistakes.
